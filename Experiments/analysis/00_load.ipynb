# %% [markdown]
# # 00 — Load experiment data
#
# Discovers every export under `Experiments/data/<condition>/`, builds the tidy tables, and caches them. **Append-only**: drop in more participants or conditions (same format) and re-run this notebook; every downstream notebook extends automatically.
#
# The thesis framing is *architectural* — the platform produces analysable data. Reading-behaviour numbers on this sample (N=2 participants) are descriptive, not inferential.

# %%
import _lib
data = _lib.load_all()
_lib.write_cache(data)
{name: len(getattr(data, name)) for name in ['sessions','gaze','fixations','saccades','interventions','context_preservation','lifecycle','telemetry']}
# Out:
# {'sessions': 8,
#  'gaze': 175860,
#  'fixations': 9311,
#  'saccades': 3225,
#  'interventions': 45,
#  'context_preservation': 19,
#  'lifecycle': 17,
#  'telemetry': 780}

# %% [markdown]
# ### Session manifest

# %%
import pandas as pd
pd.set_option('display.max_columns', 40); pd.set_option('display.width', 200)
manifest = data.sessions[['participant','condition','gazeSource','achievedHz',
    'calibrationValidationPassed','calibrationAccuracyDeg','calibrationPrecisionDeg',
    'durationSec','nGazeSamples','nFixations','nSaccades','nInterventions','nContextPreservationEvents']]
_lib.save_table(manifest, 'session_manifest')
manifest
# Out:
#   participant condition gazeSource  achievedHz  calibrationValidationPassed  calibrationAccuracyDeg  calibrationPrecisionDeg  durationSec  nGazeSamples  nFixations  nSaccades  nInterventions  \
# 0      Oliwer      with      tobii       89.98                         True                0.618923                 0.330142      185.521         16664         656        257               5
# 1      Sachin      with      tobii       90.06                         True                0.685269                 0.233362      252.218         22688        1525        412               7
# 2      Satish      with      tobii       89.41                         True                0.359789                 0.146055      171.483         15305         866        233               3
# 3      Suhani      with      tobii       90.00                         True                0.295581                 0.087724      224.043         20136         943        418               4
# 4      Oliwer   without      tobii       89.90                         True                0.470726                 0.176958      475.089         42683        1914        793               9
# 5      Sachin   without      tobii       89.84                         True                0.445445                 0.177108      123.420         11063         719        125               4
# 6      Satish   without      tobii       89.87                         True                0.380533                 0.160350      385.589         34624        1994        736              11
# 7      Suhani   without      tobii       90.02                         True                0.327637                 0.083148      141.378         12697         694        251               2
#
#    nContextPreservationEvents
# 0                           5
# 1                           7
# 2                           3
# 3                           4
# 4                           0
# 5                           0
# 6                           0
# 7                           0
