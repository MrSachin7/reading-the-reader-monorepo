# %% [markdown]
# # 04 — Modularity & graceful degradation (RQ1 / NFR4)
#
# The static modularity evidence (dependency DAG, the architecture test, modification locality, the three external providers) lives in `Experiments/architecture-evidence.md`. Here we show the runtime trace: lifecycle events recorded in the session record, including an external module provider disconnecting mid-session without interrupting the run (graceful degradation, FR19.3).

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd()))
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import _lib
_lib.apply_style()
try:
    data = _lib.read_cache()
except FileNotFoundError:
    data = _lib.load_all(); _lib.write_cache(data)

# %%
life = data.lifecycle.copy()
_lib.save_table(life, 'lifecycle_events')
life[['participant','condition','eventType','source','occurredAtUnixMs']]
# Out:
#    participant condition                 eventType                 source  \
# 0       Oliwer      with           session-started                 system
# 1       Oliwer      with           session-stopped   researcher-live-view
# 2       Sachin      with           session-started                 system
# 3       Sachin      with           session-stopped  participant-thank-you
# 4       Satish      with           session-started                 system
# 5       Satish      with           session-stopped  participant-thank-you
# 6       Suhani      with           session-started                 system
# 7       Suhani      with  module-provider-detached      fixation-analysis
# 8       Suhani      with           session-stopped   researcher-live-view
# 9       Oliwer   without           session-started                 system
# 10      Oliwer   without           session-stopped  participant-thank-you
# 11      Sachin   without           session-started                 system
# 12      Sachin   without           session-stopped  participant-thank-you
# 13      Satish   without           session-started                 system
# 14      Satish   without           session-stopped   researcher-live-view
# 15      Suhani   without           session-started                 system
# 16      Suhani   without           session-stopped   researcher-live-view
#
#     occurredAtUnixMs
# 0      1782220887541
# 1      1782221073062
# 2      1782302601614
# 3      1782302853832
# 4      1782301867800
# 5      1782302039283
# 6      1782220292205
# 7      1782220461852
# 8      1782220516248
# 9      1782221610782
# 10     1782222085871
# 11     1782302375024
# 12     1782302498444
# 13     1782301282285
# 14     1782301667874
# 15     1782219972133
# 16     1782220113511

# %%
print('lifecycle event types:', data.lifecycle['eventType'].value_counts().to_dict())
degr = data.lifecycle[data.lifecycle['eventType'] == 'module-provider-detached']
print('\nprovider-detach events (graceful degradation):')
degr[['participant','condition','source','occurredAtUnixMs']]
# Out:
# lifecycle event types: {'session-started': 8, 'session-stopped': 8, 'module-provider-detached': 1}
#
# provider-detach events (graceful degradation):
#   participant condition             source  occurredAtUnixMs
# 7      Suhani      with  fixation-analysis     1782220461852
